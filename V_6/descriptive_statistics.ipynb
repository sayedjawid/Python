# %%
import numpy as np

# list of integers 
ex = [10, 12, 11, 10, 23, 12, 24, 32, 30, 11, 10, 15, 18, 24, 23, 14, 13, 31, 23, 19, 23, 32, 17, 35, 22, 24, 24, 22, 25, 26, 25, 25, 26, 24, 23, 22]
type(ex)
# Out:
# list

# %%
np.min(ex), np.max(ex)
# Out:
# (np.int64(10), np.int64(35))

# %%
len(ex)
# Out:
# 32

# %%
# mean miyangin 
np.mean(ex)
# Out:
# np.float64(22.40625)

# %%
ex_ = sum(ex) / len(ex)
ex_
# Out:
# 22.40625

# %%
np.sort(ex)
# Out:
# array([10, 10, 10, 11, 11, 12, 12, 13, 14, 15, 17, 18, 19, 22, 22, 22, 23,
#        23, 23, 23, 23, 24, 24, 24, 24, 24, 25, 25, 25, 26, 26, 30, 31, 32,
#        32, 35])

# %%
np.mean(ex)
# Out:
# np.float64(21.11111111111111)

# %%
np.median(ex)
# Out:
# np.float64(23.0)

# %%
32 / 2
# Out:
# 16.0

# %%
np.median(np.array(ex, dtype=int))
# Out:
# np.float64(23.0)
